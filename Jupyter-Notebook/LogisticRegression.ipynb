# %% [markdown]
# ## Logistic Regression model
# - [Logistic Regression](#Logistic-Regression)
# - [Regularized Logistic Regression](#Regularized-Logistic-Regression)

# %%
# %load/../../standard_import.txt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.optimize import minimize
from sklearn.preprocessing import PolynomialFeatures

pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_seq_items', None)

# %config InlineBackend.figure_formats = {'pdf',}
# %matplotlib inline

sns.set_context('notebook')
sns.set_style('white')

# %%
def load_data(file, delimiter):
    data = np.loadtxt(file, delimiter=delimiter)
    print('Dimensions: ', data.shape)
    print(data[1:6, :])
    return (data)

# %%
def plot_data(data, label_x, label_y, label_pos, label_neg, axes=None):
    # get indices for class 0 and class 1
    neg = data[:, 2] == 0
    pos = data[:, 2] == 1

    # if no specific axes object has not been passed, get the current axes
    if axes == None:
        axes = plt.gca()
    axes.scatter(data[pos][:, 0], data[pos][:, 1], marker='+', c='k', s=60, linewidth=2, label=label_pos)
    axes.scatter(data[neg][:, 0], data[neg][:, 1], c='y', s=60, label=label_neg)
    axes.set_xlabel(label_x)
    axes.set_ylabel(label_y)
    axes.legend(frameon=True, fancybox=True);

# %% [markdown]
# ### Logistic Regression

# %%
data = load_data('data/ExamScoreData.txt', ',')
# Out:
# Dimensions:  (100, 3)
# [[30.28671077 43.89499752  0.        ]
#  [35.84740877 72.90219803  0.        ]
#  [60.18259939 86.3085521   1.        ]
#  [79.03273605 75.34437644  1.        ]
#  [45.08327748 56.31637178  0.        ]]

# %%
X = np.c_[np.ones((data.shape[0], 1)), data[:, 0:2]]
y = np.c_[data[:, 2]]

# %%
plot_data(data, 'Exam 1 score', 'Exam 2 score', 'Admitted', 'Not admitted')

# %% [markdown]
# #### Logistic regression hypothesis
# #### $$ h_{\theta}(x) = g(\theta^{T}x) $$
# #### $$ g(z) = \frac{1}{1 + e^{-z}} $$

# %%
def sigmoid(z):
    return (1 / (1 + np.exp(-z)))

# %% [markdown]
# Scipy actually has a convenience function which does exactly the same: <BR>
# http://docs.scipy.org/doc/scipy/reference/generated/scipy.special.expit.html#scipy.special.expit

# %% [markdown]
# #### Cost Function
# #### $$ J(\theta) = \frac{1}{m}\sum_{i=1}^{m}\big[-y^{(i)}\, log\,( h_\theta\,(x^{(i)})) - (1-y^{(i)})\, log\,(1-h_\theta(x^{(i)}))\big] $$
# #### Vectorized Cost Function
# #### $$ J(\theta) = \frac{1}{m}\big((\,log\,(g(X\theta))^Ty + (\,log\,(1-g(X\theta))^T(1-y)))\big) $$

# %%
def cost_function(theta, X, y):
    m = y.size
    h = sigmoid(X.dot(theta))

    J = -1 * (1/m) * (np.log(h).T.dot(y) + np.log(1-h).T.dot(1-y))

    if np.isnan(J[0]):
        return (np.inf)
    return (J[0])

# %% [markdown]
# #### Partial derivative
#
# #### $$ \frac{\delta J(\theta)}{\delta\theta_{j}} = \frac{1}{m}\sum_{i=1}^{m} ( h_\theta (x^{(i)})-y^{(i)})x^{(i)}_{j} $$
# #### Vectorized
# #### $$ \frac{\delta J(\theta)}{\delta\theta_{j}} = \frac{1}{m} X^T(g(X\theta)-y)$$

# %%
def gradient(theta, X, y):
    m = y.size
    h = sigmoid(X.dot(theta.reshape(-1, 1)))
    grad = (1/m) * X.T.dot(h - y)

    return (grad.flatten())

# %%
initial_theta = np.zeros(X.shape[1])
cost = cost_function(initial_theta, X, y)
grad = gradient(initial_theta, X, y)

print('Cost:\n', cost)
print('Gradient:\n', grad)
# Out:
# Cost:
#  0.6931471805599453
# Gradient:
#  [ -0.1        -12.00921659 -11.26284221]

# %% [markdown]
# #### Optimize Cost Function

# %%
res = minimize(cost_function, initial_theta, args=(X, y), method=None, jac=gradient, options={'maxiter':400})
res
# Out:
#       fun: 0.2034977015895099
#  hess_inv: array([[ 2.85339493e+03, -2.32908823e+01, -2.27416470e+01],
#        [-2.32908823e+01,  2.04489131e-01,  1.72969525e-01],
#        [-2.27416470e+01,  1.72969525e-01,  1.96170322e-01]])
#       jac: array([-2.68557620e-09,  4.36433485e-07, -1.39671757e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 33
#       nit: 25
#      njev: 29
#    status: 0
#   success: True
#         x: array([-25.16131634,   0.2062316 ,   0.20147143])

# %% [markdown]
# #### Predict

# %%
def predict(theta, X, threshold=0.5):
    prediction = sigmoid(X.dot(theta.T)) >= threshold

    return (prediction.astype('int'))

# %%
# Student with Exam 1 score 45 and Exam 2 score 85
# Predict using the optimized Theta values from above (res.x)
sigmoid(np.array([1, 45, 85]).dot(res.x.T))
# Out:
# 0.7762903249331021

# %%
p = predict(res.x, X)
print('Train accuracy {}%'.format(100 * sum(p == y.ravel()) / p.size))
# Out:
# Train accuracy 89.0%

# %% [markdown]
# #### Decision boundary

# %%
plt.scatter(45, 85, s=60, c='r', marker='v', label='(45, 85)')
plot_data(data, 'Exam 1 score', 'Exam 2 score', 'Admitted', 'Not admitted')

x1_min, x1_max = X[:, 1].min(), X[:, 1].max()
x2_min, x2_max = X[:, 2].min(), X[:, 2].max()
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))

h = sigmoid(np.c_[np.ones((xx1.ravel().shape[0], 1)), xx1.ravel(), xx2.ravel()].dot(res.x))
h = h.reshape(xx1.shape)
plt.contour(xx1, xx2, h, [0.5], linewidths=1, colors='b');

# %% [markdown]
# #### Regularized Logistic Regression

# %%
data = load_data('data/MicrochipData.txt', ',')
# Out:
# Dimensions:  (118, 3)
# [[-0.092742  0.68494   1.      ]
#  [-0.21371   0.69225   1.      ]
#  [-0.375     0.50219   1.      ]
#  [-0.51325   0.46564   1.      ]
#  [-0.52477   0.2098    1.      ]]

# %%
y = np.c_[data[:, 2]]
X = data[:, 0:2]

# %%
plot_data(data, 'Microchip Test 1', 'Microchip Test 2', 'y = 1', 'y = 0')

# %%
# Note that this function inserts a column with 'ones' in the design matrix for the intercept
poly = PolynomialFeatures(6)
XX = poly.fit_transform(data[:, 0:2])
XX.shape
# Out:
# (118, 28)

# %% [markdown]
# #### Regularized Cost Function
# #### $$ J(\theta) = \frac{1}{m}\sum_{i=1}^{m}\big[-y^{(i)}\, log\,( h_\theta\,(x^{(i)}))-(1-y^{(i)})\,log\,(1-h_\theta(x^{(i)}))\big] + \frac{\lambda}{2m}\sum_{j=1}^{n}\theta_{j}^{2}$$
# #### Vectorized Cost Function
# #### $$ J(\theta) = \frac{1}{m}\big((\,log\,(g(X\theta))^Ty+(\,log\,(1-g(X\theta))^T(1-y)\big) + \frac{\lambda}{2m}\sum_{j=1}^{n}\theta_{j}^{2}$$

# %%
def cost_function_regularized(theta, reg, *args):
    m = y.size
    h = sigmoid(XX.dot(theta))

    J = -1 * (1/m) * (np.log(h).T.dot(y) + np.log(1 - h).T.dot(1 - y)) + (reg / (2*m)) * np.sum(np.square(theta[1:]))

    if np.isnan(J[0]):
        return (np.inf)
    return (J[0])

# %% [markdown]
# #### Partial derivative
#
# #### $$ \frac{\delta J(\theta)}{\delta\theta_{j}} = \frac{1}{m}\sum_{i=1}^{m} ( h_\theta (x^{(i)})-y^{(i)})x^{(i)}_{j} + \frac{\lambda}{m}\theta_{j}$$
# #### Vectorized
# #### $$ \frac{\delta J(\theta)}{\delta\theta_{j}} = \frac{1}{m} X^T(g(X\theta)-y) + \frac{\lambda}{m}\theta_{j}$$
# ##### $$\text{Note: intercept parameter } \theta_{0} \text{ is not to be regularized}$$

# %%
def gradient_regularized(theta, reg, *args):
    m = y.size
    h = sigmoid(XX.dot(theta.reshape(-1, 1)))
    grad = (1/m) * XX.T.dot(h - y) + (reg/m) * np.r_[[[0]], theta[1:].reshape(-1, 1)]

    return (grad.flatten())

# %%
initial_theta = np.zeros(XX.shape[1])
cost_function_regularized(initial_theta, 1, XX, y)
# Out:
# 0.6931471805599454

# %%
fig, axes = plt.subplots(1, 3, sharey=True, figsize=(17, 5))

# Decision boundaries
# Lambda = 0 --> No regularization: too flexible, overfitting training data
# Lambda = 1 --> Looks about right
# Lambda = 100 --> Too much regularization: high bias

for i, c in enumerate([0, 1, 100]):
    # optimize cost_function_regularization
    result = minimize(cost_function_regularized, initial_theta, args=(c, XX, y), method=None, jac=gradient_regularized, options={'maxiter': 3000})

    # Accuracy
    accuracy = 100 * sum(predict(result.x, XX) == y.ravel()) / y.size

    # Scatter plot of X, y
    plot_data(data, 'Microchip Test 1', 'Microchip Test 2', 'y = 1', 'y = 0', axes.flatten()[i])

    # Plot decision boundary
    x1_min, x1_max = X[:, 0].min(), X[:, 0].max()
    x2_min, x2_max = X[:, 1].min(), X[:, 1].max()
    xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))
    h = sigmoid(poly.fit_transform(np.c_[xx1.ravel(), xx2.ravel()]).dot(result.x))
    h = h.reshape(xx1.shape)
    axes.flatten()[i].contour(xx1, xx2, h, [0.5], linewidhts=1, colors='g')
    axes.flatten()[i].set_title('Train accuracy {}% with lambda = {}'.format(np.round(accuracy, decimals=2), c))
